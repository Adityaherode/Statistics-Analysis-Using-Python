# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("../DATASETS/Global_world.csv")
df
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# ...

# %%
df.columns = df.columns.str.replace(" ","")

# %%
df.columns = df.columns.str.replace("-","")

# %%
df.columns = df.columns.str.replace("/","")

# %%
df.columns = df.columns.str.replace("[(%)]","",regex=True)

# %%
df=df.rename(columns={'Density\nPKm2':'Density','LandAreaKm2':'LandArea','Population:Laborforceparticipation':'PopulationLaborforceparticipation'})

# %%
df.columns
# Out:
# Index(['Country', 'Density', 'Abbreviation', 'AgriculturalLand', 'LandArea',
#        'ArmedForcessize', 'BirthRate', 'CallingCode', 'CapitalMajorCity',
#        'Co2Emissions', 'CPI', 'CPIChange', 'CurrencyCode', 'FertilityRate',
#        'ForestedArea', 'GasolinePrice', 'GDP',
#        'Grossprimaryeducationenrollment', 'Grosstertiaryeducationenrollment',
#        'Infantmortality', 'Largestcity', 'Lifeexpectancy',
#        'Maternalmortalityratio', 'Minimumwage', 'Officiallanguage',
#        'Outofpockethealthexpenditure', 'Physiciansperthousand', 'Population',
#        'PopulationLaborforceparticipation', 'Taxrevenue', 'Totaltaxrate',
#        'Unemploymentrate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.Density=df.Density.replace(',','',regex=True).astype('int64')

# %%
df.Density.unique()
# Out:
# array([   60,   105,    18,   164,    26,   223,    17,   104,     3,
#          109,   123,    39,  2239,  1265,   668,    47,   383,   108,
#           20,    11,    64,     4,    25,    83,    76,   463,   138,
#           95,    56,     8,    13,   153,    46,   467,    16,   100,
#           73,   106,   131,   139,    40,   137,    43,    96,   225,
#           71,   103,   313,    50,    35,    31,    67,   115,    49,
#          119,     9,   239,    57,   240,    81,   331,   167,    53,
#           70,   414,  2003,    89,   107,   464,   151,    52,    93,
#           72,   400,   206,   273,   347,     7,    94,   147,    34,
#           32,    30,   667,   238,   242,    48,   203,    99,  1802,
#         1380,   329,     5,   626,    66,   784, 26337,     2,   541,
#          508,    55,    19,   226,   214,    15,   287,   847,    58,
#          368,   124,   111,   248,    84,   525,   205,   301,   284,
# ...

# %%
df.AgriculturalLand=df.AgriculturalLand.replace('%','',regex=True)

# %%
df.AgriculturalLand=df.AgriculturalLand.fillna(0).astype('float64')

# %%
df.AgriculturalLand.unique()
# Out:
# array([58.1, 43.1, 17.4, 40. , 47.5, 20.5, 54.3, 58.9, 48.2, 32.4, 57.7,
#         1.4, 11.1, 70.6, 23.3, 42. , 44.6,  7. , 33.3, 13.6, 34.8, 45.6,
#        33.9,  2.7, 46.3, 44.2, 79.2, 64.8, 19.6, 30.9, 20.6,  6.9,  8.2,
#        39.7, 21.2, 56.2, 40.3, 71.5, 31.1, 34.5, 27.6, 59.9, 12.2, 45.2,
#        11.6, 62. , 73.4, 48.7, 22.2,  3.8, 76.4, 10.1, 75.2, 23.1,  0. ,
#        36.3,  7.5, 52.4, 20. , 59.8, 47.7, 69. , 47.6, 23.5, 36. , 59. ,
#        58. ,  8.6, 66.8, 28.9, 58.4, 18.7, 60.4, 31.5, 28.2, 21.4, 64.5,
#        24.6, 43.2, 41. , 12.3, 12. , 80.4, 48.5,  8.4, 55. , 10.3, 64.3,
#        77.6, 28. ,  8.7, 32.2, 47.2, 53.7, 71.2, 61.4, 26.3, 33.8, 63.9,
#        38.5, 42.4, 54.6, 31.4, 74.2, 19. , 68.5, 63.5, 19.5, 47.1, 28.7,
#        53.3, 40.5, 42.1, 36.1, 77.7, 21.8,  4.6, 47.8, 10.9, 30.4,  2.6,
#        55.1, 18.5, 41.7, 46.9, 39.5,  5.8, 58.8, 13.3, 25.6, 12.4, 16.7,
#        50.7, 80.8, 46.1, 39.3,  3.4, 54.7,  0.9, 39.2, 30.7,  3.9, 70.3,
# ...

# %%
df.LandArea=df.LandArea.replace(',','',regex=True)

# %%
#df.LandArea=df.LandArea.str.replace('0','',regex=True)

# %%
df.LandArea=df.LandArea.fillna(0).astype('int64')

# %%
df.LandArea.fillna(0).unique()
# Out:
# array([  652230,    28748,  2381741,      468,  1246700,      443,
#         2780400,    29743,  7741220,    83871,    86600,    13880,
#             765,   148460,      430,   207600,    30528,    22966,
#          112622,    38394,  1098581,    51197,   581730,  8515770,
#            5765,   110879,   274200,    27830,   322463,     4033,
#          181035,   475440,  9984670,   622984,  1284000,   756096,
#         9596960,  1138910,     2235,   342000,    51100,    56594,
#          110860,     9251,    78867,  2344858,    43094,    23200,
#             751,    48670,   283561,  1001450,    21041,    28051,
#          117600,    45228,    17364,  1104300,    18274,   338145,
#          643801,   267667,    11300,    69700,   357022,   238533,
#          131957,      349,   108889,   245857,    36125,   214969,
#           27750,        0,   112090,    93028,   103000,  3287263,
#         1904569,  1648195,   438317,    70273,    20770,   301340,
# ...

# %%
df.ArmedForcessize=df.ArmedForcessize.replace(',','',regex=True)

# %%
df.ArmedForcessize=df.ArmedForcessize.fillna(0).astype('int64')

# %%
df.ArmedForcessize.unique()
# Out:
# array([ 323000,    9000,  317000,       0,  117000,  105000,   49000,
#          58000,   21000,   82000,    1000,   19000,  221000,  155000,
#          32000,    2000,   12000,    6000,   71000,   11000,  730000,
#           8000,   31000,   27000,  191000,   24000,   72000,   35000,
#         122000, 2695000,  481000,   10000,   18000,   76000,   16000,
#          23000,  134000,   15000,   13000,   41000,  836000,   42000,
#         202000,  138000,    4000,   25000,  307000,    7000,   26000,
#         180000,  146000,   43000,    3000,   40000, 3031000,  676000,
#         563000,  209000,  178000,  347000,  261000,  116000,   29000,
#         129000,   80000,   34000,   22000,  136000,    5000,  336000,
#         246000,  513000,  112000,  215000, 1469000,   47000,  936000,
#         158000,  153000,   52000,  126000, 1454000,  252000,   81000,
#          20000,  634000,  185000,  196000,  124000,   30000,  239000,
# ...

# %%
df.BirthRate.fillna(0).unique().astype('float64')
# Out:
# array([32.49, 11.78, 24.28,  7.2 , 40.73, 15.33, 17.02, 13.99, 12.6 ,
#         9.7 , 14.  , 13.97, 18.18, 10.65,  9.9 , 10.3 , 20.79, 36.22,
#        17.26, 21.75,  8.11, 24.82, 13.92, 14.9 ,  8.9 , 37.93, 39.01,
#        35.74, 19.49, 22.46, 35.39, 10.1 , 35.35, 42.17, 12.43, 10.9 ,
#        14.88, 31.88, 32.86,  9.  , 10.17, 10.46, 10.7 , 41.18, 10.6 ,
#        21.47, 12.  , 19.51, 19.72, 26.38, 18.25, 33.24, 30.3 ,  0.  ,
#        32.34, 21.28,  8.6 , 11.3 , 31.61, 38.54, 13.47,  9.5 , 29.41,
#         8.1 , 16.47, 24.56, 36.36, 35.13, 19.97, 24.35, 21.6 ,  9.6 ,
#        17.86, 18.07, 18.78, 29.08, 12.5 , 20.8 ,  7.3 , 16.1 ,  7.4 ,
#        21.98, 21.77, 28.75, 27.89, 13.94, 27.1 , 23.55, 10.  , 17.55,
#        26.81, 33.04, 18.83, 32.66, 34.12, 16.75, 14.2 , 41.54,  9.2 ,
#        29.03, 33.69, 10.2 , 17.6 , 22.82,  5.9 , 24.13, 11.73, 18.94,
#        37.52, 28.64, 19.89, 11.98, 20.64, 46.08, 37.91, 13.89, 10.4 ,
# ...

# %%
df.CallingCode.fillna(0).unique().astype('float64')
# Out:
# array([9.300e+01, 3.550e+02, 2.130e+02, 3.760e+02, 2.440e+02, 1.000e+00,
#        5.400e+01, 3.740e+02, 6.100e+01, 4.300e+01, 9.940e+02, 9.730e+02,
#        8.800e+02, 3.750e+02, 3.200e+01, 5.010e+02, 2.290e+02, 9.750e+02,
#        5.910e+02, 3.870e+02, 2.670e+02, 5.500e+01, 6.730e+02, 3.590e+02,
#        2.260e+02, 2.570e+02, 2.250e+02, 2.380e+02, 8.550e+02, 2.370e+02,
#        2.360e+02, 2.350e+02, 5.600e+01, 8.600e+01, 5.700e+01, 2.690e+02,
#        2.420e+02, 5.060e+02, 3.850e+02, 5.300e+01, 3.570e+02, 4.200e+02,
#        2.430e+02, 4.500e+01, 2.530e+02, 5.930e+02, 2.000e+01, 5.030e+02,
#        2.400e+02, 2.910e+02, 3.720e+02, 2.680e+02, 2.510e+02, 6.790e+02,
#        3.580e+02, 3.300e+01, 2.410e+02, 2.200e+02, 9.950e+02, 4.900e+01,
#        2.330e+02, 3.000e+01, 5.020e+02, 2.240e+02, 2.450e+02, 5.920e+02,
#        5.090e+02, 3.790e+02, 5.040e+02, 3.600e+01, 3.540e+02, 9.100e+01,
#        6.200e+01, 9.800e+01, 9.640e+02, 3.530e+02, 9.720e+02, 3.900e+01,
# ...

# %%
df[df.CapitalMajorCity=='S����']
# Out:
#           Country  Density Abbreviation  AgriculturalLand  LandArea  \
# 150  S�����������      228           ST              50.7       964
#
#      ArmedForcessize  BirthRate  CallingCode CapitalMajorCity Co2Emissions  \
# 150             1000      31.54        239.0            S����          121
#
#      ... Outofpockethealthexpenditure Physiciansperthousand Population  \
# 150  ...                       11.70%                  0.05    215,056
#
#      PopulationLaborforceparticipation Taxrevenue Totaltaxrate  \
# 150                             57.80%     14.60%       37.00%
#
#     Unemploymentrate Urban_population Latitude  Longitude
# 150           13.37%          158,277      NaN        NaN
#
# [1 rows x 35 columns]

# %%
df= df.drop(labels=150,axis=0)

# %%
df.Largestcity.unique()
# Out:
# array(['Kabul', 'Tirana', 'Algiers', 'Andorra la Vella', 'Luanda',
#        "St. John's, Saint John", 'Buenos Aires', 'Yerevan', 'Sydney',
#        'Vienna', 'Baku', 'Nassau, Bahamas', 'Riffa', 'Dhaka',
#        'Bridgetown', 'Minsk', 'Brussels', 'Belize City', 'Cotonou',
#        'Thimphu', 'Santa Cruz de la Sierra', 'Tuzla Canton', 'Gaborone',
#        'S����', nan, 'Sofia', 'Ouagadougou', 'Bujumbura', 'Abidjan',
#        'Praia', 'Phnom Penh', 'Douala', 'Toronto', 'Bangui', "N'Djamena",
#        'Santiago', 'Shanghai', 'Bogot�', 'Moroni, Comoros', 'Brazzaville',
#        'San Jos������', 'Zagreb', 'Havana', 'Statos�������', 'Prague',
#        'Kinshasa', 'Copenhagen', 'Djibouti City', 'Roseau',
#        'Santo Domingo', 'Quito', 'Cairo', 'San Salvador', 'Malabo',
#        'Asmara', 'Tallinn', 'Mbabane', 'Addis Ababa', 'Suva', 'Helsinki',
#        'Paris', 'Libreville', 'Serekunda', 'Tbilisi', 'Berlin', 'Accra',
# ...

# %%
df[df.Largestcity=='S����']
# Out:
#    Country  Density Abbreviation  AgriculturalLand  LandArea  ArmedForcessize  \
# 23  Brazil       25           BR              33.9   8515770           730000
#
#     BirthRate  CallingCode CapitalMajorCity Co2Emissions  ...  \
# 23      13.92         55.0          Bras���      462,299  ...
#
#    Outofpockethealthexpenditure Physiciansperthousand   Population  \
# 23                       28.30%                  2.15  212,559,417
#
#     PopulationLaborforceparticipation Taxrevenue Totaltaxrate  \
# 23                             63.90%     14.20%       65.10%
#
#    Unemploymentrate Urban_population   Latitude  Longitude
# 23           12.08%      183,241,641 -14.235004  -51.92528
#
# [1 rows x 35 columns]

# %%
df= df.drop(labels=23,axis=0)

# %%
df[df.Largestcity=='S�����']
# Out:
#     Country  Density Abbreviation  AgriculturalLand  LandArea  \
# 168  Sweden       25           SE               7.4    450295
#
#      ArmedForcessize  BirthRate  CallingCode CapitalMajorCity Co2Emissions  \
# 168            30000       11.4         46.0        Stockholm       43,252
#
#      ... Outofpockethealthexpenditure Physiciansperthousand  Population  \
# 168  ...                       15.20%                  3.98  10,285,453
#
#      PopulationLaborforceparticipation Taxrevenue Totaltaxrate  \
# 168                             64.60%     27.90%       49.10%
#
#     Unemploymentrate Urban_population   Latitude  Longitude
# 168            6.48%        9,021,165  60.128161  18.643501
#
# [1 rows x 35 columns]

# %%
df= df.drop(labels=168,axis=0)

# %%
df[df.Largestcity=='Z���']
# Out:
#          Country  Density Abbreviation  AgriculturalLand  LandArea  \
# 169  Switzerland      219           CH              38.4     41277
#
#      ArmedForcessize  BirthRate  CallingCode CapitalMajorCity Co2Emissions  \
# 169            21000       10.0         41.0             Bern       34,477
#
#      ... Outofpockethealthexpenditure Physiciansperthousand Population  \
# 169  ...                       28.30%                   4.3  8,574,832
#
#      PopulationLaborforceparticipation Taxrevenue Totaltaxrate  \
# 169                             68.30%     10.10%       28.80%
#
#     Unemploymentrate Urban_population   Latitude  Longitude
# 169            4.58%        6,332,428  46.818188   8.227512
#
# [1 rows x 35 columns]

# %%
df= df.drop(labels=169,axis=0)

# %%
df.Largestcity.replace('�','',regex=True).unique()
# Out:
# array(['Kabul', 'Tirana', 'Algiers', 'Andorra la Vella', 'Luanda',
#        "St. John's, Saint John", 'Buenos Aires', 'Yerevan', 'Sydney',
#        'Vienna', 'Baku', 'Nassau, Bahamas', 'Riffa', 'Dhaka',
#        'Bridgetown', 'Minsk', 'Brussels', 'Belize City', 'Cotonou',
#        'Thimphu', 'Santa Cruz de la Sierra', 'Tuzla Canton', 'Gaborone',
#        nan, 'Sofia', 'Ouagadougou', 'Bujumbura', 'Abidjan', 'Praia',
#        'Phnom Penh', 'Douala', 'Toronto', 'Bangui', "N'Djamena",
#        'Santiago', 'Shanghai', 'Bogot', 'Moroni, Comoros', 'Brazzaville',
#        'San Jos', 'Zagreb', 'Havana', 'Statos', 'Prague', 'Kinshasa',
#        'Copenhagen', 'Djibouti City', 'Roseau', 'Santo Domingo', 'Quito',
#        'Cairo', 'San Salvador', 'Malabo', 'Asmara', 'Tallinn', 'Mbabane',
#        'Addis Ababa', 'Suva', 'Helsinki', 'Paris', 'Libreville',
#        'Serekunda', 'Tbilisi', 'Berlin', 'Accra', 'Macedonia',
#        "St. George's, Grenada", 'Guatemala City', 'Kankan', 'Bissau',
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Density', 'Abbreviation', 'AgriculturalLand', 'LandArea',
#        'ArmedForcessize', 'BirthRate', 'CallingCode', 'CapitalMajorCity',
#        'Co2Emissions', 'CPI', 'CPIChange', 'CurrencyCode', 'FertilityRate',
#        'ForestedArea', 'GasolinePrice', 'GDP',
#        'Grossprimaryeducationenrollment', 'Grosstertiaryeducationenrollment',
#        'Infantmortality', 'Largestcity', 'Lifeexpectancy',
#        'Maternalmortalityratio', 'Minimumwage', 'Officiallanguage',
#        'Outofpockethealthexpenditure', 'Physiciansperthousand', 'Population',
#        'PopulationLaborforceparticipation', 'Taxrevenue', 'Totaltaxrate',
#        'Unemploymentrate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df=df.drop(['CallingCode','CurrencyCode','Latitude','Longitude'],axis=1)

# %%
df.fillna(0)
# Out:
#          Country  Density Abbreviation  AgriculturalLand  LandArea  \
# 0    Afghanistan       60           AF              58.1    652230
# 1        Albania      105           AL              43.1     28748
# 2        Algeria       18           DZ              17.4   2381741
# 3        Andorra      164           AD              40.0       468
# 4         Angola       26           AO              47.5   1246700
# ..           ...      ...          ...               ...       ...
# 190    Venezuela       32           VE              24.5    912050
# 191      Vietnam      314           VN              39.3    331210
# 192        Yemen       56           YE              44.6    527968
# 193       Zambia       25           ZM              32.1    752618
# 194     Zimbabwe       38           ZW              41.9    390757
#
#      ArmedForcessize  BirthRate  CapitalMajorCity Co2Emissions       CPI  ...  \
# 0             323000      32.49             Kabul        8,672     149.9  ...
# ...
